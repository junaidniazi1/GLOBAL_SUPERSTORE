# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_excel('/content/Global Superstore.xls')

# %%
data
# Out:
#        Row ID         Order ID Order Date  Ship Date       Ship Mode  \
# 0       32298   CA-2012-124891 2012-07-31 2012-07-31        Same Day
# 1       26341    IN-2013-77878 2013-02-05 2013-02-07    Second Class
# 2       25330    IN-2013-71249 2013-10-17 2013-10-18     First Class
# 3       13524  ES-2013-1579342 2013-01-28 2013-01-30     First Class
# 4       47221     SG-2013-4320 2013-11-05 2013-11-06        Same Day
# ...       ...              ...        ...        ...             ...
# 51285   29002    IN-2014-62366 2014-06-19 2014-06-19        Same Day
# 51286   35398   US-2014-102288 2014-06-20 2014-06-24  Standard Class
# 51287   40470   US-2013-155768 2013-12-02 2013-12-02        Same Day
# 51288    9596   MX-2012-140767 2012-02-18 2012-02-22  Standard Class
# 51289    6147   MX-2012-134460 2012-05-22 2012-05-26    Second Class
#
#       Customer ID     Customer Name      Segment           City  \
# 0        RH-19495       Rick Hansen     Consumer  New York City
# ...

# %%
data.isnull().sum()
# Out:
# Row ID                0
# Order ID              0
# Order Date            0
# Ship Date             0
# Ship Mode             0
# Customer ID           0
# Customer Name         0
# Segment               0
# City                  0
# State                 0
# Country               0
# Postal Code       41296
# Market                0
# Region                0
# Product ID            0
# Category              0
# Sub-Category          0
# Product Name          0
# Sales                 0
# Quantity              0
# Discount              0
# Profit                0
# Shipping Cost         0
# Order Priority        0
# dtype: int64

# %%
data.drop(['Postal Code'],axis=1,inplace=True)

# %%
data.isnull().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# City              0
# State             0
# Country           0
# Market            0
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# Quantity          0
# Discount          0
# Profit            0
# Shipping Cost     0
# Order Priority    0
# dtype: int64

# %%
data.describe()
# Out:
#             Row ID                     Order Date  \
# count  51290.00000                          51290
# mean   25645.50000  2013-05-11 21:26:49.155781120
# min        1.00000            2011-01-01 00:00:00
# 25%    12823.25000            2012-06-19 00:00:00
# 50%    25645.50000            2013-07-08 00:00:00
# 75%    38467.75000            2014-05-22 00:00:00
# max    51290.00000            2014-12-31 00:00:00
# std    14806.29199                            NaN
#
#                            Ship Date         Sales      Quantity  \
# count                          51290  51290.000000  51290.000000
# mean   2013-05-15 20:42:42.745174528    246.490581      3.476545
# min              2011-01-03 00:00:00      0.444000      1.000000
# 25%              2012-06-23 00:00:00     30.758625      2.000000
# 50%              2013-07-12 00:00:00     85.053000      3.000000
# 75%              2014-05-26 00:00:00    251.053200      5.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  datetime64[ns]
#  3   Ship Date       51290 non-null  datetime64[ns]
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   City            51290 non-null  object
#  9   State           51290 non-null  object
#  10  Country         51290 non-null  object
#  11  Market          51290 non-null  object
#  12  Region          51290 non-null  object
#  13  Product ID      51290 non-null  object
#  14  Category        51290 non-null  object
#  15  Sub-Category    51290 non-null  object
# ...

# %%
data.shape
# Out:
# (51290, 23)

# %%
data.sav

# %%
data.to_csv('global_superstore.csv', index=False)

# %%
people=pd.read_csv('/content/people.csv')

# %%
duplicates = people.duplicated()

# Count how many duplicates
print("Number of duplicate rows:", duplicates.sum())

# View duplicate rows (optional)
print("Duplicate rows:")
print(people[duplicates])

# Remove duplicates
df_cleaned_people = people.drop_duplicates()

# Confirm removal
print("New shape after removing duplicates:", df_cleaned_people.shape)
# Out:
# Number of duplicate rows: 0
# Duplicate rows:
# Empty DataFrame
# Columns: [Person, Region]
# Index: []
# New shape after removing duplicates: (13, 2)

# %%
returns=pd.read_csv('/content/returned.csv')

# %%
duplicates = returns.duplicated()

# Count how many duplicates
print("Number of duplicate rows:", duplicates.sum())

# View duplicate rows (optional)
print("Duplicate rows:")
print(returns[duplicates])

# Remove duplicates
df_cleaned_returns = returns.drop_duplicates()

# Confirm removal
print("New shape after removing duplicates:", df_cleaned_returns.shape)
# Out:
# Number of duplicate rows: 0
# Duplicate rows:
# Empty DataFrame
# Columns: [Returned, Order ID, Market]
# Index: []
# New shape after removing duplicates: (1173, 3)

# %%
# Mapping dictionary
market_mapping = {
    "United States": "US",
    "LATAM": "LATAM",
    "EU": "EU",
    "APAC": "APAC",
    "Africa": "Africa",
    "Canada": "Canada",
    "EMEA": "EMEA"
}

# Apply mapping to Market column in the 'returned' DataFrame
df_cleaned_returns['Market'] = df_cleaned_returns['Market'].replace(market_mapping)

# %%
df_cleaned_people
# Out:
#                   Person          Region
# 0          Anna Andreadi         Central
# 1            Chuck Magee           South
# 2         Kelly Williams            East
# 3         Matt Collister            West
# 4      Deborah Brumfield          Africa
# 5           Larry Hughes            AMEA
# 6          Nicole Hansen          Canada
# 7       Giulietta Dortch       Caribbean
# 8             Nora Preis    Central Asia
# 9            Jack Lebron           North
# 10       Shirley Daniels      North Asia
# 11        Anthony Jacobs         Oceania
# 12  Alejandro Ballentine  Southeast Asia

# %%
df_cleaned_returns
# Out:
#      Returned         Order ID Market
# 0         Yes   MX-2013-168137  LATAM
# 1         Yes   US-2011-165316  LATAM
# 2         Yes  ES-2013-1525878     EU
# 3         Yes   CA-2013-118311     US
# 4         Yes  ES-2011-1276768     EU
# ...       ...              ...    ...
# 1168      Yes  ES-2013-2639112     EU
# 1169      Yes   CA-2014-134194     US
# 1170      Yes  ES-2012-3246286     EU
# 1171      Yes  ES-2012-4379168     EU
# 1172      Yes   CA-2014-168193     US
#
# [1173 rows x 3 columns]

# %%
import pandas as pd

df_main = pd.read_csv('/content/global_superstore.csv', parse_dates=['Order Date', 'Ship Date'])
# Check how many duplicate rows (entire rows are the same)
duplicates = df_main.duplicated()
print("Duplicate rows found:", duplicates.sum())

# Optionally: View those duplicates
# print(df_main[duplicates])
# Check how many duplicate rows (entire rows are the same)
duplicates = df_main.duplicated()
print("Duplicate rows found:", duplicates.sum())

# Optionally: View those duplicates
# print(df_main[duplicates])
# Remove duplicate rows
df_main_cleaned = df_main.drop_duplicates()

# Confirm new shape
print("Shape after removing duplicates:", df_main_cleaned.shape)
# Out:
# Duplicate rows found: 0
# Duplicate rows found: 0
# Shape after removing duplicates: (51290, 23)

# %%
df_merged = pd.merge(df_main_cleaned, df_cleaned_returns, on='Order ID', how='left')

# %%
# If 'Market_y' exists and 'Market_x' is from original
df_merged['Market'] = df_merged['Market_y'].combine_first(df_merged['Market_x'])
df_merged.drop(columns=['Market_x', 'Market_y'], inplace=True)

# %%
df_merged = pd.merge(df_merged, df_cleaned_people, on='Region', how='left')

# %%
print("Final merged dataset shape:", df_merged.shape)
print(df_merged.columns)
# Out:
# Final merged dataset shape: (51295, 25)
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Country',
#        'Region', 'Product ID', 'Category', 'Sub-Category', 'Product Name',
#        'Sales', 'Quantity', 'Discount', 'Profit', 'Shipping Cost',
#        'Order Priority', 'Returned', 'Market', 'Person'],
#       dtype='object')

# %%
df_merged
# Out:
#        Row ID         Order ID Order Date  Ship Date       Ship Mode  \
# 0       32298   CA-2012-124891 2012-07-31 2012-07-31        Same Day
# 1       26341    IN-2013-77878 2013-02-05 2013-02-07    Second Class
# 2       25330    IN-2013-71249 2013-10-17 2013-10-18     First Class
# 3       13524  ES-2013-1579342 2013-01-28 2013-01-30     First Class
# 4       47221     SG-2013-4320 2013-11-05 2013-11-06        Same Day
# ...       ...              ...        ...        ...             ...
# 51290   29002    IN-2014-62366 2014-06-19 2014-06-19        Same Day
# 51291   35398   US-2014-102288 2014-06-20 2014-06-24  Standard Class
# 51292   40470   US-2013-155768 2013-12-02 2013-12-02        Same Day
# 51293    9596   MX-2012-140767 2012-02-18 2012-02-22  Standard Class
# 51294    6147   MX-2012-134460 2012-05-22 2012-05-26    Second Class
#
#       Customer ID     Customer Name      Segment           City  \
# 0        RH-19495       Rick Hansen     Consumer  New York City
# ...

# %%
df_merged.isnull().sum()
# Out:
# Row ID                0
# Order ID              0
# Order Date            0
# Ship Date             0
# Ship Mode             0
# Customer ID           0
# Customer Name         0
# Segment               0
# City                  0
# State                 0
# Country               0
# Region                0
# Product ID            0
# Category              0
# Sub-Category          0
# Product Name          0
# Sales                 0
# Quantity              0
# Discount              0
# Profit                0
# Shipping Cost         0
# Order Priority        0
# Returned          48240
# Market                0
# Person             5029
# dtype: int64

# %%
# 1. Drop the 'Returned' column
df_merged = df_merged.drop(columns=['Returned'])

# 2. Handle nulls in 'Person' column
# Option A: Fill with a placeholder like 'Unassigned'
df_merged['Person'] = df_merged['Person'].fillna('Unassigned')

# ✅ Final check
print(df_merged['Person'].isnull().sum())  # Should be 0
print(df_merged.columns)
# Out:
# 0
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Country',
#        'Region', 'Product ID', 'Category', 'Sub-Category', 'Product Name',
#        'Sales', 'Quantity', 'Discount', 'Profit', 'Shipping Cost',
#        'Order Priority', 'Market', 'Person'],
#       dtype='object')

# %%
df_merged.isnull().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# City              0
# State             0
# Country           0
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# Quantity          0
# Discount          0
# Profit            0
# Shipping Cost     0
# Order Priority    0
# Market            0
# Person            0
# dtype: int64

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51295 entries, 0 to 51294
# Data columns (total 25 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51295 non-null  int64
#  1   Order ID        51295 non-null  object
#  2   Order Date      51295 non-null  datetime64[ns]
#  3   Ship Date       51295 non-null  datetime64[ns]
#  4   Ship Mode       51295 non-null  object
#  5   Customer ID     51295 non-null  object
#  6   Customer Name   51295 non-null  object
#  7   Segment         51295 non-null  object
#  8   City            51295 non-null  object
#  9   State           51295 non-null  object
#  10  Country         51295 non-null  object
#  11  Region          51295 non-null  object
#  12  Product ID      51295 non-null  object
#  13  Category        51295 non-null  object
#  14  Sub-Category    51295 non-null  object
#  15  Product Name    51295 non-null  object
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Optional settings
sns.set(style="whitegrid")
# %matplotlib inline

# %% [markdown]
# ## 📊  Sales Overview

# %%
# Total sales, profit, and average per order
print("Total Sales: ", df_merged['Sales'].sum())
print("Total Profit: ", df_merged['Profit'].sum())
print("Average Profit per Order: ", df_merged.groupby('Order ID')['Profit'].sum().mean())
# Out:
# Total Sales:  12643249.909880001
# Total Profit:  1467556.1110799997
# Average Profit per Order:  58.620176196524866

# %% [markdown]
# ## 📈 Time Series: Sales Over Time

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Convert Order Date to datetime (in case it's not)
df_merged['Order Date'] = pd.to_datetime(df_merged['Order Date'])

# Create a proper datetime-based Month column as string (not Period)
df_merged['Order Month'] = df_merged['Order Date'].dt.to_period('M').astype(str)

# Group sales by Order Month
monthly_sales = df_merged.groupby('Order Month')['Sales'].sum().reset_index()

# Ensure 'Sales' is numeric (optional safety check)
monthly_sales['Sales'] = pd.to_numeric(monthly_sales['Sales'], errors='coerce')

# Plot the trend
plt.figure(figsize=(12,5))
sns.lineplot(x='Order Month', y='Sales', data=monthly_sales, marker='o')
plt.xticks(rotation=45)
plt.title("Monthly Sales Trend")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 🧩 Segment and Region Analysis

# %%
# Sales by Segment
segment_sales = df_merged.groupby('Segment')['Sales'].sum().reset_index()
sns.barplot(data=segment_sales, x='Segment', y='Sales')
plt.title("Sales by Customer Segment")
plt.show()

# Profit by Region
region_profit = df_merged.groupby('Region')['Profit'].sum().reset_index()
sns.barplot(data=region_profit, x='Region', y='Profit')
plt.xticks(rotation=45)
plt.title("Profit by Region")
plt.show()

# %% [markdown]
# ## 🛍️  Product Performance

# %%
# Top 10 profitable products
top_products = df_merged.groupby('Product Name')['Profit'].sum().sort_values(ascending=False).head(10)
top_products.plot(kind='barh', figsize=(8,5), title="Top 10 Profitable Products")

# Top sub-categories by sales
plt.figure(figsize=(10,5))
sns.barplot(y='Sub-Category', x='Sales', data=df_merged, estimator=sum, order=df_merged.groupby('Sub-Category')['Sales'].sum().sort_values().index)
plt.title("Sales by Sub-Category")
# Out:
# Text(0.5, 1.0, 'Sales by Sub-Category')

# %% [markdown]
# ## 🚚  Shipping & Discount Effects

# %%
# Shipping Cost vs Profit
sns.scatterplot(x='Shipping Cost', y='Profit', data=df_merged)
plt.title("Shipping Cost vs Profit")

# Discount vs Profit
sns.scatterplot(x='Discount', y='Profit', data=df_merged)
plt.title("Discount vs Profit")
# Out:
# Text(0.5, 1.0, 'Discount vs Profit')

# %% [markdown]
# ## 🔁👥  Manager/Person Performance

# %%
# Sales by Manager
manager_sales = df_merged.groupby('Person')['Sales'].sum().sort_values(ascending=False).head(10)
manager_sales.plot(kind='barh', title="Top 10 Managers by Sales", figsize=(8,5))
# Out:
# <Axes: title={'center': 'Top 10 Managers by Sales'}, ylabel='Person'>

# %% [markdown]
# ## 📌  Correlation Heatmap

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df_merged[['Sales', 'Profit', 'Quantity', 'Discount', 'Shipping Cost']].corr(), annot=True, cmap='coolwarm')
plt.title("Feature Correlation Heatmap")
# Out:
# Text(0.5, 1.0, 'Feature Correlation Heatmap')

# %%
import pandas as pd

# If not already parsed
# df_merged['Order Date'] = pd.to_datetime(df_merged['Order Date'])

# ------------------------------
# 🎯 KPI 1: Total Sales
total_sales = df_merged['Sales'].sum()

# 🎯 KPI 2: Total Profit
total_profit = df_merged['Profit'].sum()

# 🎯 KPI 3: Profit Margin
profit_margin = (total_profit / total_sales) if total_sales else 0

# 🎯 KPI 4: Total Customers
total_customers = df_merged['Customer ID'].nunique()

# 🎯 KPI 5: Repeat Purchase Rate
customer_order_counts = df_merged.groupby('Customer ID')['Order ID'].nunique()
repeat_customers = (customer_order_counts > 1).sum()
repeat_purchase_rate = repeat_customers / total_customers if total_customers else 0

# 🎯 KPI 6: Churn Rate (monthly)
df_merged['Order Month'] = df_merged['Order Date'].dt.to_period('M')
monthly_customers = df_merged.groupby('Order Month')['Customer ID'].nunique()

# Calculate churn (optional: smooth with moving average)
churn_rate = monthly_customers.diff().fillna(0) / monthly_customers.shift(1).fillna(1)
avg_churn_rate = churn_rate.mean()

# 🎯 KPI 7: Average Order Value
total_orders = df_merged['Order ID'].nunique()
average_order_value = total_sales / total_orders if total_orders else 0

# 🎯 KPI 8: Average Quantity per Order
average_quantity_per_order = df_merged.groupby('Order ID')['Quantity'].sum().mean()

# 🎯 KPI 9: Return Rate (if 'Returned' column exists)
if 'Returned' in df_merged.columns:
    total_returns = df_merged[df_merged['Returned'] == 'Yes']['Order ID'].nunique()
    return_rate = total_returns / total_orders if total_orders else 0
else:
    return_rate = None

# 🎯 KPI 10: Customer Lifetime Value (Simple version)
# Avg revenue per customer * repeat purchase rate
avg_revenue_per_customer = total_sales / total_customers if total_customers else 0
clv = avg_revenue_per_customer * repeat_purchase_rate

# %%
print("🧾 Total Sales: {:.2f}".format(total_sales))
print("💰 Total Profit: {:.2f}".format(total_profit))
print("📊 Profit Margin: {:.2%}".format(profit_margin))
print("🧍‍♂️ Total Customers:", total_customers)
print("🔁 Repeat Purchase Rate: {:.2%}".format(repeat_purchase_rate))
print("📉 Avg Monthly Churn Rate: {:.2%}".format(avg_churn_rate))
print("🛍️ Average Order Value: {:.2f}".format(average_order_value))
print("📦 Avg Quantity per Order: {:.2f}".format(average_quantity_per_order))
if return_rate is not None:
    print("🔄 Return Rate: {:.2%}".format(return_rate))
print("🧑‍💼 Customer Lifetime Value (CLV): {:.2f}".format(clv))
# Out:
# 🧾 Total Sales: 12643249.91
# 💰 Total Profit: 1467556.11
# 📊 Profit Margin: 11.61%
# 🧍‍♂️ Total Customers: 1590
# 🔁 Repeat Purchase Rate: 99.37%
# 📉 Avg Monthly Churn Rate: 6.94%
# 🛍️ Average Order Value: 505.02
# 📦 Avg Quantity per Order: 7.12
# 🧑‍💼 Customer Lifetime Value (CLV): 7901.72

# %%
df_merged.to_csv('cleanded_global_superstore.csv', index=False)
